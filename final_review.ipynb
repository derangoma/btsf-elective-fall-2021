# %% [markdown]
# # welcome to the final review
#
# this is going to be a series of questions going over everything we worked on over these past few classes

# %% [markdown]
# 1) fill in a function that implements the fibonacci sequence:
#
# 0, 1, 1, 2, 3, 5, 8, 13...
#
# with the n=1 term of the sequence being zero
#
# and verify the outputs are correct

# %%
def fib(n):
    # your code here #

# %%
assert fib(1) == 0
assert fib(3) == 1
assert fib(8) == 13

# %% [markdown]
# 2) implement the following function in python
#
# ![image.png](attachment:image.png)

# %%
def func(x):
    # your code here #

# %%
assert func(10) == 15
assert func(20) == 45
assert func(30) == 25
assert func(40) == 35

# %% [markdown]
# 3) write a function that returns the maximum of 3 values
#
# for example, for inputs a=1, b=4, c=3, return 4

# %%
def maximum(a, b, c):
    # your code here #

# %%
assert maximum(1, 4, 3) == 4
assert maximum(-5, 1, 2) == 2
assert maximum(0, 0, -1) == 0
assert maximum(0, -4, -100) == 0

# %% [markdown]
# 4) write a function that accepts a list as an argument and prints every OTHER element
#
# for example, given the list:
#
# ```python
# [1, 2, 3, 4, 5, 6, 7]
# ```
#
# your function should print:
#
# 1
#
# 3
#
# 5
#
# 7

# %%
def print_every_other(x):
    # your code here #

# %%
print_every_other([1, 2, 3, 4, 6, 7])

# %%
print_every_other([3, 1, 3, 2, 3, 3, 3, 4, 3])

# %% [markdown]
# 5) using any method you want, write a function that returns the sum of all numbers up to n
#
# for example, if n=5, we want to return 1+2+3+4+5=15
#
# so `cumulative_sum(5) == 15`

# %%
def cumulative_sum(n):
    # your code here #

# %%
assert cumulative_sum(1) == 1
assert cumulative_sum(3) == 6
assert cumulative_sum(5) == 15
assert cumulative_sum(10) == 55
